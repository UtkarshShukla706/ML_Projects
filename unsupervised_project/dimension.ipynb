# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
X,y=make_blobs(n_samples=500,n_features=5,centers=3,random_state=42,cluster_std=1.5)

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
pca=PCA(n_components=2)
X_pca=pca.fit_transform(X_scaled)

# %%
df_pca=pd.DataFrame(X_pca,columns=['PC1','PC2'])
df_pca['label']=y

# %%
sns.scatterplot(data=df_pca,x='PC1',y='PC2',hue='label',palette='viridis')
# Out:
# <Axes: xlabel='PC1', ylabel='PC2'>

# %%
#so here we can see the 5d adta in the 2d plane by using the dimensionality reduction of the data
